# %% [markdown]
# <a href="https://colab.research.google.com/github/arshad831/Python_basics/blob/main/emi_calculator_6thsep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Next, let's add the interest calculation into the function. Here's the formula used to calculate the EMI for a loan:
#
# ![image.png](data:image/png;base64,...)
#
# where:
#
# P is the loan amount (principal)
# n is the no. of months
# r is the rate of interest per month
# The derivation of this formula is beyond the scope of this tutorial. See this video for an explanation: https://youtu.be/Coxza9ugW4E .

# %%
def loan_emi(amount, duration, rate, down_payment=0):
    loan_amount = amount - down_payment
    emi = loan_amount * rate * ((1+rate)**duration) / (((1+rate)**duration)-1)
    return round(emi,2)
